# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path().resolve().parents[0]  # notebooks/ is one level down
sys.path.append(str(PROJECT_ROOT / "src"))

# %%
from config import CFG, ensure_dirs
ensure_dirs(CFG)

# %%
from utils import load_kagglehub_dataset
#TODO: check best practice way to do this

# %%
df = load_kagglehub_dataset(CFG.dataset_id, CFG.file_path)

df.head()

#TODO: pause to set up API keys?
# https://www.kaggle.com/docs/api#authentication
# https://www.kaggle.com/datasets/pxxthik/the-cocktail-db-recipe-collection?select=ingredients.csv

# schema = schema_overview(df)
# schema.to_csv(CFG.tables_dir / "schema_overview.csv")

# id_col = "idDrink" if "idDrink" in df.columns else None
# ing_long = extract_ingredients_long(df, id_col=id_col)
# ing_long.to_csv(CFG.tables_dir / "ingredients_long.csv", index=False)

# freq = ingredient_frequency(ing_long)
# freq.to_csv(CFG.tables_dir / "ingredient_frequency.csv", index=False)

# plot_top_ingredients(freq, top_n=CFG.top_n_ingredients,
#                      outpath=CFG.figures_dir / "top_ingredients.png")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df = load_kagglehub_dataset(CFG.dataset_id, CFG.file_path)
#       3 df.head()
#       5 # schema = schema_overview(df)
#       6 # schema.to_csv(CFG.tables_dir / "schema_overview.csv")
#       7
#    (...)     15 # plot_top_ingredients(freq, top_n=CFG.top_n_ingredients,
#      16 #                      outpath=CFG.figures_dir / "top_ingredients.png")
#
# File ~/repos/chatGnT/src/utils.py:15, in load_kagglehub_dataset(dataset_id, file_path, pandas_kwargs)
#      13 """Load dataset using KaggleHub."""
#      14 pandas_kwargs = pandas_kwargs or {}
# ---> 15 df = kagglehub.load_dataset(
#      16     KaggleDatasetAdapter.PANDAS,
#      17     dataset_id,
#      18     file_path,
#      19     pandas_kwargs=pandas_kwargs
#      20 )
#      21 return df
#
# ...
